# %%
from life_time_backcouzin_repulsionground import *

# %% [markdown]
# # For video generation

# %%
simulation(w1=20,w2=40,ti=7000,si=20,aa=14,video=True)
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # for value generate only

# %%
tankk, ss, pp, dd, staytime, gotime, backtime, am, tank_go, tank_end=simulation(w1=20,w2=40,ti=7000,si=20,aa=14,video=False)
